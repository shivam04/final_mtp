# %%
import pandas as pd
import numpy as np
import glob, os, sys
import time
import pickle
import datetime

# %%
with open('finalset/preprocess_5_hours.pickle', 'rb') as handle:
    [matrix3D,  outcomes] = pickle.load(handle)
    print("yes")
print("here")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-2-46346c2f4153> in <module>()
#       1 with open('finalset/preprocess_5_hours.pickle', 'rb') as handle:
# ----> 2     [matrix3D,  outcomes] = pickle.load(handle)
#       3     print("yes")
#       4 print("here")
#
# UnicodeDecodeError: 'ascii' codec can't decode byte 0xf0 in position 43: ordinal not in range(128)

# %%
matrix3D
# Out:
# array([[[0.        , 0.        , 0.        , ..., 0.        ,
#          0.02173913, 0.        ],
#         [0.        , 0.        , 0.        , ..., 0.        ,
#          0.02173913, 0.        ],
#         [0.        , 0.        , 0.        , ..., 0.        ,
#          0.02173913, 0.        ],
#         [0.        , 0.        , 0.        , ..., 0.        ,
#          0.02173913, 0.        ],
#         [0.        , 0.        , 0.        , ..., 0.        ,
#          0.02173913, 0.        ]],
#
#        [[0.        , 0.        , 0.        , ..., 0.        ,
#          0.        , 0.23450704],
#         [0.        , 0.        , 0.        , ..., 0.        ,
#          0.        , 0.23450704],
#         [0.        , 0.        , 0.        , ..., 0.        ,
#          0.        , 0.23450704],
#         [0.        , 0.        , 0.        , ..., 0.        ,
#          0.        , 0.23450704],
#         [0.        , 0.        , 0.        , ..., 0.        ,
# ...

# %%
outcomes
# Out:
#       SUBJECT_ID  LABEL
# 0             17      0
# 1             21      0
# 2             23      0
# 3             34      0
# 4             36      1
# 5             61      0
# 6             68      1
# 7             85      0
# 8             94      0
# 9            103      1
# 10           105      1
# 11           107      0
# 12           109      1
# 13           111      0
# 14           112      0
# 15           117      0
# 16           124      1
# 17           130      1
# 18           138      0
# 19           145      0
# 20           154      0
# 21           156      0
# 22           157      1
# 23           175      0
# 24           177      0
# 25           184      0
# 26           188      0
# 27           191      0
# 28           199      0
# 29           203      0
# ...          ...    ...
# 6557       99260      0
# 6558       99268      0
# 6559       99299      1
# 6560       99312      1
# 6561       99322      0
# 6562       99339      0
# ...
